# %% [markdown]
# Programa: Ejemplo factorial en python Autor: Grupo 1 2022_2 Fecha: 26_09_2022 Versión:1.0 ""

# %%
facM=1
facN=1
facMN=1

m= int(input("Digite número M:"))
n= int(input("Digite número N:"))

if (m>=n);
    #Factorial de M
    for i in range(1,m+1);
    facM=facM*1
    print("El factorial es: ", fac)

    #Factorial de N
    for i in range(1,n+1);
    facN=FacN*1
    print("El factorial es: ", facN)

    #Factorial de MN
     for i in range(1(m-n+1));
    facMN=FacMN*i
    print("El factorial M-N: ", facMN)

    #Calcular combinatorio
    com=facM/(facN/*facMN)
    print("")

else
    print("Error - M no es mayor que N")
