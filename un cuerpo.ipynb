# %% [markdown]
# Un cuerpo posee una velocidad inicial de 12 m/s y una aceleracion de 2 m/s2¿cuanto tiempo tardara en adquirir una velocidad de 144km/h?

# %%
vf=144*(1000/3600)
conversion=int(input("Ingrese el número...:"))
print("Conversion de km/s a m/s",conversion,"*1000/3600")
print("El resultado de la conversion es...",vf,"m/s")
# Out:
# Ingrese el número...:144
# Conversion de km/s a m/s 144 *1000/3600
# El resultado de la conversion es... 40.0 m/s

# %% [markdown]
# Fórmula para calcular tiempo

# %%
vf=int(input("ingrese la velocidad final en m/s:  "))
vi=int(input("Ingrese la velocidad inicial en m/s:  "))
a=int(input("Ingrese la aceleración en m/s:   "))
t=((vf-vi)/a)
print("la resta de las velocidades es:  ",vf-vi)
print("El tiempo es que tarda en adquirir una velocidad de 40 m/s: ",t)
# Out:
# ingrese la velocidad final en m/s:  40
# Ingrese la velocidad inicial en m/s:  12
# Ingrese la aceleración en m/s:   2
# la resta de las velocidades es:   28
# El tiempo es que tarda en adquirir una velocidad de 40 m/s:  14.0
