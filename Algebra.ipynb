# %%
from sympy import *

# %%
A = Matrix ([[1,1,2,3],[0,0,0,0]])
B = Matrix ([[1,1,0,0],[1,1,0,0]])

# %%
print (A,B)
# Out:
# Matrix([[1, 1, 2, 3], [0, 0, 0, 0]]) Matrix([[1, 1, 0, 0], [1, 1, 0, 0]])

# %%
A
# Out:
# Matrix([
# [1, 1, 2, 3],
# [0, 0, 0, 0]])

# %%
B
# Out:
# Matrix([
# [1, 1, 0, 0],
# [1, 1, 0, 0]])
