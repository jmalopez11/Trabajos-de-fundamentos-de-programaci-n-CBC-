# %% [markdown]
# Ejercicio 1

# %%
vinicial= int(input("m/s...")) 
vfinal= int(input("m/s..."))
tiempo= int(input("s..."))
# Out:
# m/s...20
# m/s...25
# s...5

# %%
"""declaración de las variables"""
vinicial=20;
vfinal=25;
tiempo=5;

# %%
A=(( vfinal-vinicial)/tiempo)

# %%
print("la aceleración del camión es de m/s")
print(A)
# Out:
# la aceleración del camión es de m/s
# 1.0

# %% [markdown]
# ejercicio 2

# %%
vinicial=int(input("km/h..."));
tiempo=int(input("s..."));
sol=int(input("s2..."));
# Out:
# km/h...216
# s...10
# s2...6

# %%
"""declaración de las variables"""
vinicial=216;
tiempo=10;
sol=6;

# %%
A=((vinicial-sol)/tiempo)

# %%
print("la aceleración del fórmula 1 es de m/s")
print(A)
# Out:
# la aceleración del fórmula 1 es de m/s
# 21.0

# %% [markdown]
# ejercicio 3

# %%
vinicial=int(input("m/s..."))
tiempo=int(input("s..."))
sol=int(input("m/s2..."))
# Out:
# m/s...25
# s...10
# m/s2...125

# %%
"""declaración de variables"""
vinicial=20;
tiempo=10;
sol=125;

# %%
A=((vinicial-sol)/tiempo)

# %%
print("la aceleración de la locomotora es m/s")
print(A)
# Out:
# la aceleración de la locomotora es m/s
# -10.5

# %% [markdown]
# ejercicio 4

# %%
vinicial=int(input("m/s..."))
vfinal=int(input("km/h"))
aceleración=int(input("m/s2"))
# Out:
# m/s...12
# km/h144
# m/s22

# %%
"""declaración de las variables"""
vinicial=12;
vfinal=144;
aceleración=2;

# %%
A=((vfinal-vinicial)/aceleración)

# %%
print("el tiempo que el cuerpo tardara en alcanzar la velocidad de 144 es de m/s")
print(A)
# Out:
# el tiempo que el cuerpo tardara en alcanzar la velocidad de 144 es de m/s
# 66.0
