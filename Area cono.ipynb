# %% [markdown]
# Calcular el área de un cono de altura inclinada 15 cm y diámetro 6 cm.

# %%
import numpy as np
a=int(input("Ingrese la altura inclinada en cm..."));
D=int(input("Ingrese el diámetro en cm..."));
R=int(input("Ingrese el radio del cono en cm..."));
A=(np.pi*R*(R+a))
print("El area del cono es",A)
# Out:
# Ingrese la altura inclinada en cm...15
# Ingrese el diámetro en cm...6
# Ingrese el radio del cono en cm...3
# El area del cono es 169.64600329384882
